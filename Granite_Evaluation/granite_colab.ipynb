# %% [markdown]
# **Running on GPU T4**

# %%
# %%capture
# !pip install torch transformers bitsandbytes accelerate sqlparse

# %%
import torch
from transformers import AutoTokenizer,AutoModelForCausalLM

# %%
torch.cuda.is_available()
# Out:
# True

# %% [markdown]
# **Load Model in 4-bit**

# %%
device = "cuda" # or "cpu"
model_path = "ibm-granite/granite-8b-code-instruct"
tokenizer = AutoTokenizer.from_pretrained(model_path)
model = AutoModelForCausalLM.from_pretrained(model_path, load_in_4bit=True,
    device_map=device ,use_cache=True)
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# The `load_in_4bit` and `load_in_8bit` arguments are deprecated and will be removed in the future versions. Please, pass a `BitsAndBytesConfig` object in `quantization_config` argument instead.
# model.safetensors.index.json:   0%|          | 0.00/46.8k [00:00<?, ?B/s]
# Downloading shards:   0%|          | 0/4 [00:00<?, ?it/s]
# model-00001-of-00004.safetensors:   0%|          | 0.00/4.97G [00:00<?, ?B/s]
# model-00002-of-00004.safetensors:   0%|          | 0.00/4.92G [00:00<?, ?B/s]
# model-00003-of-00004.safetensors:   0%|          | 0.00/4.97G [00:00<?, ?B/s]
# model-00004-of-00004.safetensors:   0%|          | 0.00/1.26G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/137 [00:00<?, ?B/s]

# %%
prompt = """

Write a SQL query to answer the following question given the database schema.Please wrap your code answer using ```:

Schema:

CREATE TABLE Employees (
    EmployeeID INT PRIMARY KEY,
    FirstName VARCHAR(50),
    LastName VARCHAR(50),
    Email VARCHAR(100),
    Department VARCHAR(50),
    Position VARCHAR(50),
    Salary DECIMAL(10, 2)
);

CREATE TABLE EmployeeDetails (
    EmployeeID INT PRIMARY KEY,
    BirthDate DATE,
    Address VARCHAR(100),
    City VARCHAR(50),
    State VARCHAR(50),
    ZipCode VARCHAR(20),
    Phone VARCHAR(20),
    FOREIGN KEY (EmployeeID) REFERENCES Employees(EmployeeID)
);

Question: `{question}`:
```sql
"""

# %%
import sqlparse

def generate_query(question):
    updated_prompt = prompt.format(question=question)
    inputs = tokenizer(updated_prompt, return_tensors="pt").to("cuda")
    generated_ids = model.generate(
        **inputs,
        num_return_sequences=1,
        eos_token_id=tokenizer.eos_token_id,
        pad_token_id=tokenizer.eos_token_id,
        max_new_tokens=400,
        do_sample=False,
        num_beams=1,
        temperature=0.0,
        top_p=1,
    )
    outputs = tokenizer.batch_decode(generated_ids, skip_special_tokens=True)

    torch.cuda.empty_cache()
    torch.cuda.synchronize()
    # empty cache so that you do generate more results w/o memory crashing
    # particularly important on Colab – memory management is much more straightforward
    # when running on an inference service
    # return sqlparse.format(outputs[0].split("[SQL]")[-1], reindent=True)
    return outputs[0].split("```sql")[1].split(";")[0]

# %% [markdown]
# **To run a single  query**

# %%
import time
t1 = time.perf_counter()
question = "Retrieve all columns for employees with an EmployeeID less than 10."
generated_sql = generate_query(question)
print(sqlparse.format(generated_sql, reindent=True))
t2 = time.perf_counter()
print('time taken to run:',t2-t1)
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/generation/configuration_utils.py:515: UserWarning: `do_sample` is set to `False`. However, `temperature` is set to `0.0` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `temperature`.
#   warnings.warn(
# SELECT *
# FROM Employees
# WHERE EmployeeID < 10
# time taken to run: 2.637418959999877

# %% [markdown]
# **We will  be evaluating it on 20 sql questions**

# %%
sql_questions = [
    "Retrieve all columns for employees with an EmployeeID less than 10.",
    "Retrieve the first name and salary of employees in the IT department.",
    "Count the number of employees in each department.",
    "Retrieve employees whose salary is greater than $70,000.",
    "Retrieve employees sorted by last name in descending order.",
    "Calculate the average salary of employees.",
    "Retrieve employees birth after January 1st, 1982.",
    "Retrieve employees with the first name starting with 'J'.",
    "Retrieve employees sorted by department and position.",
    "Retrieve employees with no assigned department.",
    "Retrieve employees along with their detailed information (from EmployeeDetails).",
    "Calculate the total number of employees and average salary per department.",
    "Retrieve the employee details who live in cities that have more than one employee, along with the count of employees in those cities.",
    "Retrieve employees with salaries between $60,000 and $80,000, sorted by salary.",
    "Retrieve the top 3 highest paid employees.",
    "Retrieve the department with the highest average salary.",
    "Retrieve employees who are earning more than the average salary of their department.",
    "Retrieve the total number of employees in each city and their average salary.",
    "Retrieve the youngest and oldest employees' details along with their ages.",
    "Retrieve employees who have the same last name as any other employee."
]

# %%
len(sql_questions)
# Out:
# 20

# %%
import time
t1 = time.perf_counter()
model_response=  []

for i in sql_questions:
    response = generate_query(i)
    model_response.append(response)
t2 = time.perf_counter()
print('time taken to execute 20 SQL queries:',t2-t1)
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/generation/configuration_utils.py:515: UserWarning: `do_sample` is set to `False`. However, `temperature` is set to `0.0` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `temperature`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/bitsandbytes/nn/modules.py:426: UserWarning: Input type into Linear4bit is torch.float16, but bnb_4bit_compute_dtype=torch.float32 (default). This will lead to slow inference or training speed.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/transformers/generation/configuration_utils.py:515: UserWarning: `do_sample` is set to `False`. However, `temperature` is set to `0.0` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `temperature`.
#   warnings.warn(
# time taken to execute 20 SQL queries: 92.61764750099996

# %%
import pandas as pd
ground_truth = [
    "SELECT * FROM Employees WHERE EmployeeID < 10;",
    "SELECT FirstName, Salary FROM Employees WHERE Department = 'IT';",
    "SELECT Department, COUNT(*) AS NumEmployees FROM Employees GROUP BY Department;",
    "SELECT * FROM Employees WHERE Salary > 70000;",
    "SELECT * FROM Employees ORDER BY LastName DESC;",
    "SELECT AVG(Salary) AS AvgSalary FROM Employees;",
    "SELECT * FROM EmployeeDetails WHERE BirthDate > '1982-01-01'",
    "SELECT * FROM Employees WHERE FirstName LIKE 'J%';",
    "SELECT * FROM Employees ORDER BY Department, Position;",
    "SELECT * FROM Employees WHERE Department IS NULL;",
    "SELECT E.*, ED.BirthDate, ED.Address, ED.City, ED.State, ED.ZipCode, ED.Phone FROM Employees E JOIN EmployeeDetails ED ON E.EmployeeID = ED.EmployeeID;",
    "SELECT Department, COUNT(*) AS NumEmployees, AVG(Salary) AS AvgSalary FROM Employees GROUP BY Department;",
    "SELECT ed.City, COUNT(ed.EmployeeID) AS EmployeeCount, GROUP_CONCAT(e.FirstName, ' ', e.LastName) AS EmployeeNames FROM EmployeeDetails ed JOIN Employees e ON ed.EmployeeID = e.EmployeeID GROUP BY ed.City HAVING COUNT(ed.EmployeeID) > 1 ORDER BY EmployeeCount DESC;",
    "SELECT * FROM Employees WHERE Salary BETWEEN 60000 AND 80000 ORDER BY Salary;",
    "SELECT * FROM Employees ORDER BY Salary DESC LIMIT 3;",
    "SELECT Department, AVG(Salary) AS AvgSalary FROM Employees GROUP BY Department ORDER BY AvgSalary DESC LIMIT 1;",
    "SELECT E.* FROM Employees E JOIN (SELECT Department, AVG(Salary) AS AvgSalary FROM Employees GROUP BY Department) AS AvgSalaries ON E.Department = AvgSalaries.Department WHERE E.Salary > AvgSalaries.AvgSalary;",
    "SELECT ED.City, COUNT(*) AS NumEmployees, AVG(E.Salary) AS AvgSalary FROM Employees E JOIN EmployeeDetails ED ON E.EmployeeID = ED.EmployeeID GROUP BY ED.City;",
    "SELECT e.FirstName, e.LastName, ed.BirthDate, TIMESTAMPDIFF(YEAR, ed.BirthDate, CURDATE()) AS Age, CASE WHEN ed.BirthDate = (SELECT MIN(BirthDate) FROM EmployeeDetails) THEN 'Oldest' WHEN ed.BirthDate = (SELECT MAX(BirthDate) FROM EmployeeDetails) THEN 'Youngest' END AS AgeCategory FROM EmployeeDetails ed JOIN Employees e ON ed.EmployeeID = e.EmployeeID WHERE ed.BirthDate = (SELECT MIN(BirthDate) FROM EmployeeDetails) OR ed.BirthDate = (SELECT MAX(BirthDate) FROM EmployeeDetails);",
    "SELECT E1.EmployeeID, E1.FirstName, E1.LastName FROM Employees E1 JOIN Employees E2 ON E1.LastName = E2.LastName AND E1.EmployeeID != E2.EmployeeID;"
]

# Create a DataFrame
df = pd.DataFrame({
    'Question': sql_questions,
    'Ground Truth Query':ground_truth ,
    'Granite Response (LLM)': model_response ,
    'Query Level':['simple','simple','simple','simple','simple','simple','simple','simple','simple','simple','medium','medium','medium','medium','medium','complex','complex','complex','complex','complex'],
    'Match':['correct','correct' ,'correct','correct','correct','correct' ,'correct','correct','correct','correct','correct','correct','wrong','correct','wrong','correct','correct','wrong','wrong','correct']
})

# %%
df
# Out:
#                                              Question  \
# 0   Retrieve all columns for employees with an Emp...
# 1   Retrieve the first name and salary of employee...
# 2   Count the number of employees in each department.
# 3   Retrieve employees whose salary is greater tha...
# 4   Retrieve employees sorted by last name in desc...
# 5          Calculate the average salary of employees.
# 6   Retrieve employees birth after January 1st, 1982.
# 7   Retrieve employees with the first name startin...
# 8   Retrieve employees sorted by department and po...
# 9     Retrieve employees with no assigned department.
# 10  Retrieve employees along with their detailed i...
# 11  Calculate the total number of employees and av...
# 12  Retrieve the employee details who live in citi...
# 13  Retrieve employees with salaries between $60,0...
# 14         Retrieve the top 3 highest paid employees.
# 15  Retrieve the department with the highest avera...
# 16  Retrieve employees who are earning more than t...
# 17  Retrieve the total number of employees in each...
# 18  Retrieve the youngest and oldest employees' de...
# 19  Retrieve employees who have the same last name...
#
#                                    Ground Truth Query  \
# 0      SELECT * FROM Employees WHERE EmployeeID < 10;
# 1   SELECT FirstName, Salary FROM Employees WHERE ...
# 2   SELECT Department, COUNT(*) AS NumEmployees FR...
# 3       SELECT * FROM Employees WHERE Salary > 70000;
# 4     SELECT * FROM Employees ORDER BY LastName DESC;
# 5     SELECT AVG(Salary) AS AvgSalary FROM Employees;
# 6   SELECT * FROM EmployeeDetails WHERE BirthDate ...
# 7   SELECT * FROM Employees WHERE FirstName LIKE '...
# 8   SELECT * FROM Employees ORDER BY Department, P...
# 9   SELECT * FROM Employees WHERE Department IS NULL;
# 10  SELECT E.*, ED.BirthDate, ED.Address, ED.City,...
# 11  SELECT Department, COUNT(*) AS NumEmployees, A...
# 12  SELECT ed.City, COUNT(ed.EmployeeID) AS Employ...
# 13  SELECT * FROM Employees WHERE Salary BETWEEN 6...
# 14  SELECT * FROM Employees ORDER BY Salary DESC L...
# 15  SELECT Department, AVG(Salary) AS AvgSalary FR...
# 16  SELECT E.* FROM Employees E JOIN (SELECT Depar...
# 17  SELECT ED.City, COUNT(*) AS NumEmployees, AVG(...
# 18  SELECT e.FirstName, e.LastName, ed.BirthDate, ...
# 19  SELECT E1.EmployeeID, E1.FirstName, E1.LastNam...
#
#                                Granite Response (LLM) Query Level    Match
# 0     \nSELECT * FROM Employees WHERE EmployeeID < 10      simple  correct
# 1   \nSELECT FirstName, Salary\nFROM Employees\nWH...      simple  correct
# 2   \nSELECT COUNT(*) AS NumberOfEmployees, Depart...      simple  correct
# 3    \nSELECT *\nFROM Employees\nWHERE Salary > 70000      simple  correct
# 4    \nSELECT * FROM Employees ORDER BY LastName DESC      simple  correct
# 5                 \nSELECT AVG(Salary) FROM Employees      simple  correct
# 6   \nSELECT *\nFROM EmployeeDetails\nWHERE BirthD...      simple  correct
# 7   \nSELECT * FROM Employees WHERE FirstName LIKE...      simple  correct
# 8   \nSELECT * FROM Employees\nORDER BY Department...      simple  correct
# 9   \nSELECT FirstName, LastName, Email\nFROM Empl...      simple  correct
# 10  \nSELECT *\nFROM Employees\nINNER JOIN Employe...      medium  correct
# 11  \nSELECT COUNT(EmployeeID), AVG(Salary)\nFROM ...      medium  correct
# 12  \nSELECT City, COUNT(*) AS EmployeeCount\nFROM...      medium    wrong
# 13  \nSELECT *\nFROM Employees\nWHERE Salary BETWE...      medium  correct
# 14  \nSELECT TOP 3 FirstName, LastName, Salary\nFR...      medium    wrong
# 15  \nSELECT Department, AVG(Salary) AS AvgSalary\...     complex  correct
# 16  \nSELECT *\nFROM Employees\nWHERE Salary > (\n...     complex  correct
# 17  \nSELECT City, COUNT(*) AS NumberOfEmployees, ...     complex    wrong
# 18  \nSELECT \n    FirstName, \n    LastName, \n  ...     complex    wrong
# 19  \nSELECT FirstName, LastName, Email, Departmen...     complex  correct

# %%
df.to_csv("granite.csv")

# %% [markdown]
# **Time took to execute 20 queries is 92 seconds . Out of 20  questions , 2 are wrong with level as medium and 2 from complex level**

# %% [markdown]
# **Now , lets see how much time it will  take to run 20  queries on cpu**

# %%
# %%capture
# !pip install sqlparse

# %%
torch.cuda.is_available()
# Out:
# False

# %%
# !pip install llama-cpp-python
# !pip install langchain_community

# %%
# !wget https://huggingface.co/ibm-granite/granite-8b-code-instruct-GGUF/resolve/main/granite-8b-code-instruct.Q4_K_M.gguf?download=true

# %%
from langchain_community.llms import LlamaCpp
from langchain_core.prompts import PromptTemplate
# GLOBAL VARIABLES
my_model_path = "/content/granite-8b-code-instruct.Q4_K_M.gguf?download=true"
# LOAD THE MODEL
model = LlamaCpp(model_path=my_model_path,temperature=0.0,top_p=1)
# Out:
# llama_model_loader: loaded meta data with 26 key-value pairs and 578 tensors from /content/granite-8b-code-instruct.Q4_K_M.gguf?download=true (version GGUF V3 (latest))
# llama_model_loader: Dumping metadata keys/values. Note: KV overrides do not apply in this output.
# llama_model_loader: - kv   0:                       general.architecture str              = llama
# llama_model_loader: - kv   1:                               general.name str              = granite-8b-code-instruct
# llama_model_loader: - kv   2:                          llama.block_count u32              = 36
# llama_model_loader: - kv   3:                       llama.context_length u32              = 4096
# llama_model_loader: - kv   4:                     llama.embedding_length u32              = 4096
# llama_model_loader: - kv   5:                  llama.feed_forward_length u32              = 14336
# llama_model_loader: - kv   6:                 llama.attention.head_count u32              = 32
# llama_model_loader: - kv   7:              llama.attention.head_count_kv u32              = 8
# llama_model_loader: - kv   8:                       llama.rope.freq_base f32              = 10000.000000
# llama_model_loader: - kv   9:     llama.attention.layer_norm_rms_epsilon f32              = 0.000010
# llama_model_loader: - kv  10:                          general.file_type u32              = 15
# llama_model_loader: - kv  11:                           llama.vocab_size u32              = 49152
# llama_model_loader: - kv  12:                 llama.rope.dimension_count u32              = 128
# llama_model_loader: - kv  13:            tokenizer.ggml.add_space_prefix bool             = false
# llama_model_loader: - kv  14:               tokenizer.ggml.add_bos_token bool             = false
# llama_model_loader: - kv  15:                       tokenizer.ggml.model str              = gpt2
# llama_model_loader: - kv  16:                         tokenizer.ggml.pre str              = refact
# llama_model_loader: - kv  17:                      tokenizer.ggml.tokens arr[str,49152]   = ["<|endoftext|>", "<fim_prefix>", "<f...
# llama_model_loader: - kv  18:                  tokenizer.ggml.token_type arr[i32,49152]   = [3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, ...
# llama_model_loader: - kv  19:                      tokenizer.ggml.merges arr[str,48891]   = ["Ġ Ġ", "ĠĠ ĠĠ", "ĠĠĠĠ ĠĠ...
# llama_model_loader: - kv  20:                tokenizer.ggml.bos_token_id u32              = 0
# llama_model_loader: - kv  21:                tokenizer.ggml.eos_token_id u32              = 0
# llama_model_loader: - kv  22:            tokenizer.ggml.unknown_token_id u32              = 0
# llama_model_loader: - kv  23:            tokenizer.ggml.padding_token_id u32              = 0
# llama_model_loader: - kv  24:                    tokenizer.chat_template str              = {% for message in messages %}\n{% if m...
# llama_model_loader: - kv  25:               general.quantization_version u32              = 2
# llama_model_loader: - type  f32:  325 tensors
# llama_model_loader: - type q4_K:  216 tensors
# llama_model_loader: - type q6_K:   37 tensors
# llm_load_vocab: special tokens cache size = 19
# llm_load_vocab: token to piece cache size = 0.2826 MB
# llm_load_print_meta: format           = GGUF V3 (latest)
# llm_load_print_meta: arch             = llama
# llm_load_print_meta: vocab type       = BPE
# llm_load_print_meta: n_vocab          = 49152
# llm_load_print_meta: n_merges         = 48891
# llm_load_print_meta: n_ctx_train      = 4096
# llm_load_print_meta: n_embd           = 4096
# llm_load_print_meta: n_head           = 32
# llm_load_print_meta: n_head_kv        = 8
# llm_load_print_meta: n_layer          = 36
# llm_load_print_meta: n_rot            = 128
# llm_load_print_meta: n_swa            = 0
# llm_load_print_meta: n_embd_head_k    = 128
# llm_load_print_meta: n_embd_head_v    = 128
# llm_load_print_meta: n_gqa            = 4
# llm_load_print_meta: n_embd_k_gqa     = 1024
# llm_load_print_meta: n_embd_v_gqa     = 1024
# llm_load_print_meta: f_norm_eps       = 0.0e+00
# llm_load_print_meta: f_norm_rms_eps   = 1.0e-05
# llm_load_print_meta: f_clamp_kqv      = 0.0e+00
# llm_load_print_meta: f_max_alibi_bias = 0.0e+00
# llm_load_print_meta: f_logit_scale    = 0.0e+00
# llm_load_print_meta: n_ff             = 14336
# llm_load_print_meta: n_expert         = 0
# llm_load_print_meta: n_expert_used    = 0
# llm_load_print_meta: causal attn      = 1
# llm_load_print_meta: pooling type     = 0
# llm_load_print_meta: rope type        = 0
# llm_load_print_meta: rope scaling     = linear
# llm_load_print_meta: freq_base_train  = 10000.0
# llm_load_print_meta: freq_scale_train = 1
# llm_load_print_meta: n_ctx_orig_yarn  = 4096
# llm_load_print_meta: rope_finetuned   = unknown
# llm_load_print_meta: ssm_d_conv       = 0
# llm_load_print_meta: ssm_d_inner      = 0
# llm_load_print_meta: ssm_d_state      = 0
# llm_load_print_meta: ssm_dt_rank      = 0
# llm_load_print_meta: model type       = 8B
# llm_load_print_meta: model ftype      = Q4_K - Medium
# llm_load_print_meta: model params     = 8.05 B
# llm_load_print_meta: model size       = 4.55 GiB (4.85 BPW)
# llm_load_print_meta: general.name     = granite-8b-code-instruct
# llm_load_print_meta: BOS token        = 0 '<|endoftext|>'
# llm_load_print_meta: EOS token        = 0 '<|endoftext|>'
# llm_load_print_meta: UNK token        = 0 '<|endoftext|>'
# llm_load_print_meta: PAD token        = 0 '<|endoftext|>'
# llm_load_print_meta: LF token         = 145 'Ä'
# llm_load_print_meta: EOT token        = 0 '<|endoftext|>'
# llm_load_print_meta: max token length = 512
# llm_load_tensors: ggml ctx size =    0.24 MiB
# llm_load_tensors:        CPU buffer size =  4654.98 MiB
# ................................................................................................
# llama_new_context_with_model: n_batch is less than GGML_KQ_MASK_PAD - increasing to 32
# llama_new_context_with_model: n_ctx      = 512
# llama_new_context_with_model: n_batch    = 32
# llama_new_context_with_model: n_ubatch   = 32
# llama_new_context_with_model: flash_attn = 0
# llama_new_context_with_model: freq_base  = 10000.0
# llama_new_context_with_model: freq_scale = 1
# llama_kv_cache_init:        CPU KV buffer size =    72.00 MiB
# llama_new_context_with_model: KV self size  =   72.00 MiB, K (f16):   36.00 MiB, V (f16):   36.00 MiB
# llama_new_context_with_model:        CPU  output buffer size =     0.19 MiB
# llama_new_context_with_model:        CPU compute buffer size =     6.50 MiB
# llama_new_context_with_model: graph nodes  = 1410
# llama_new_context_with_model: graph splits = 1
# AVX = 1 | AVX_VNNI = 0 | AVX2 = 1 | AVX512 = 0 | AVX512_VBMI = 0 | AVX512_VNNI = 0 | AVX512_BF16 = 0 | FMA = 1 | NEON = 0 | SVE = 0 | ARM_FMA = 0 | F16C = 1 | FP16_VA = 0 | WASM_SIMD = 0 | BLAS = 0 | SSE3 = 1 | SSSE3 = 1 | VSX = 0 | MATMUL_INT8 = 0 | LLAMAFILE = 0 |
# Model metadata: {'tokenizer.chat_template': "{% for message in messages %}\n{% if message['role'] == 'user' %}\n{{ 'Question:\n' + message['content'] + '\n\n' }}{% elif message['role'] == 'system' %}\n{{ 'System:\n' + message['content'] + '\n\n' }}{% elif message['role'] == 'assistant' %}{{ 'Answer:\n'  + message['content'] + '\n\n' }}{% endif %}\n{% if loop.last and add_generation_prompt %}\n{{ 'Answer:\n' }}{% endif %}{% endfor %}", 'tokenizer.ggml.padding_token_id': '0', 'tokenizer.ggml.unknown_token_id': '0', 'tokenizer.ggml.eos_token_id': '0', 'general.quantization_version': '2', 'tokenizer.ggml.model': 'gpt2', 'tokenizer.ggml.add_space_prefix': 'false', 'general.architecture': 'llama', 'llama.rope.freq_base': '10000.000000', 'tokenizer.ggml.pre': 'refact', 'llama.context_length': '4096', 'general.name': 'granite-8b-code-instruct', 'tokenizer.ggml.add_bos_token': 'false', 'llama.embedding_length': '4096', 'llama.feed_forward_length': '14336', 'llama.attention.layer_norm_rms_epsilon': '0.000010', 'tokenizer.ggml.bos_token_id': '0', 'llama.attention.head_count': '32', 'llama.block_count': '36', 'llama.attention.head_count_kv': '8', 'general.file_type': '15', 'llama.vocab_size': '49152', 'llama.rope.dimension_count': '128'}
# Available chat formats from metadata: chat_template.default
# Using gguf chat template: {% for message in messages %}
# {% if message['role'] == 'user' %}
# {{ 'Question:
# ' + message['content'] + '
#
# ' }}{% elif message['role'] == 'system' %}
# {{ 'System:
# ' + message['content'] + '
#
# ' }}{% elif message['role'] == 'assistant' %}{{ 'Answer:
# '  + message['content'] + '
#
# ' }}{% endif %}
# {% if loop.last and add_generation_prompt %}
# {{ 'Answer:
# ' }}{% endif %}{% endfor %}
# Using chat eos_token: <|endoftext|>
# Using chat bos_token: <|endoftext|>

# %%
template = """

Write a SQL query to answer the following question given the database schema.Please wrap your code answer using ```:

Schema:

CREATE TABLE Employees (
    EmployeeID INT PRIMARY KEY,
    FirstName VARCHAR(50),
    LastName VARCHAR(50),
    Email VARCHAR(100),
    Department VARCHAR(50),
    Position VARCHAR(50),
    Salary DECIMAL(10, 2)
);

CREATE TABLE EmployeeDetails (
    EmployeeID INT PRIMARY KEY,
    BirthDate DATE,
    Address VARCHAR(100),
    City VARCHAR(50),
    State VARCHAR(50),
    ZipCode VARCHAR(20),
    Phone VARCHAR(20),
    FOREIGN KEY (EmployeeID) REFERENCES Employees(EmployeeID)
);

Question: `{question}`:
```sql
"""
prompt = PromptTemplate.from_template(template=template)

# %%
llm_chain = prompt | model

# %%
import sqlparse
response = llm_chain.invoke("Retrieve all columns for employees with an EmployeeID less than 10.")
print(sqlparse.format(response))
# Out:
# llama_print_timings:        load time =    6702.78 ms
# llama_print_timings:      sample time =      16.32 ms /    16 runs   (    1.02 ms per token,   980.45 tokens per second)
# llama_print_timings: prompt eval time =  141439.03 ms /   192 tokens (  736.66 ms per token,     1.36 tokens per second)
# llama_print_timings:        eval time =   12918.83 ms /    15 runs   (  861.26 ms per token,     1.16 tokens per second)
# llama_print_timings:       total time =  154430.95 ms /   207 tokens
# SELECT * FROM Employees WHERE EmployeeID < 10;
# ```

# %%
import time
t1 = time.perf_counter()
model_response=  []

for i in sql_questions:
    response = llm_chain.invoke(i)
    model_response.append(response)
t2 = time.perf_counter()
print('time taken to execute 20 SQL queries on cpu:',t2-t1)
# Out:
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =    6702.78 ms
# llama_print_timings:      sample time =      15.40 ms /    16 runs   (    0.96 ms per token,  1038.76 tokens per second)
# llama_print_timings: prompt eval time =       0.00 ms /     0 tokens (    -nan ms per token,     -nan tokens per second)
# llama_print_timings:        eval time =   15587.42 ms /    16 runs   (  974.21 ms per token,     1.03 tokens per second)
# llama_print_timings:       total time =   15625.60 ms /    16 tokens
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =    6702.78 ms
# llama_print_timings:      sample time =      17.64 ms /    18 runs   (    0.98 ms per token,  1020.18 tokens per second)
# llama_print_timings: prompt eval time =    8707.22 ms /    16 tokens (  544.20 ms per token,     1.84 tokens per second)
# llama_print_timings:        eval time =   15531.01 ms /    18 runs   (  862.83 ms per token,     1.16 tokens per second)
# llama_print_timings:       total time =   24274.24 ms /    34 tokens
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =    6702.78 ms
# llama_print_timings:      sample time =      18.22 ms /    19 runs   (    0.96 ms per token,  1042.98 tokens per second)
# llama_print_timings: prompt eval time =    6753.22 ms /    14 tokens (  482.37 ms per token,     2.07 tokens per second)
# llama_print_timings:        eval time =   15229.63 ms /    18 runs   (  846.09 ms per token,     1.18 tokens per second)
# llama_print_timings:       total time =   22020.34 ms /    32 tokens
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =    6702.78 ms
# llama_print_timings:      sample time =      18.57 ms /    19 runs   (    0.98 ms per token,  1023.43 tokens per second)
# llama_print_timings: prompt eval time =   10801.18 ms /    20 tokens (  540.06 ms per token,     1.85 tokens per second)
# llama_print_timings:        eval time =   15202.68 ms /    18 runs   (  844.59 ms per token,     1.18 tokens per second)
# llama_print_timings:       total time =   26045.23 ms /    38 tokens
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =    6702.78 ms
# llama_print_timings:      sample time =      13.84 ms /    14 runs   (    0.99 ms per token,  1011.56 tokens per second)
# llama_print_timings: prompt eval time =    7655.57 ms /    13 tokens (  588.89 ms per token,     1.70 tokens per second)
# llama_print_timings:        eval time =   11183.11 ms /    13 runs   (  860.24 ms per token,     1.16 tokens per second)
# llama_print_timings:       total time =   18867.29 ms /    26 tokens
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =    6702.78 ms
# llama_print_timings:      sample time =      15.10 ms /    16 runs   (    0.94 ms per token,  1059.60 tokens per second)
# llama_print_timings: prompt eval time =    5813.44 ms /    12 tokens (  484.45 ms per token,     2.06 tokens per second)
# llama_print_timings:        eval time =   12778.87 ms /    15 runs   (  851.92 ms per token,     1.17 tokens per second)
# llama_print_timings:       total time =   18624.14 ms /    27 tokens
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =    6702.78 ms
# llama_print_timings:      sample time =      25.04 ms /    25 runs   (    1.00 ms per token,   998.24 tokens per second)
# llama_print_timings: prompt eval time =   11255.47 ms /    20 tokens (  562.77 ms per token,     1.78 tokens per second)
# llama_print_timings:        eval time =   20813.08 ms /    24 runs   (  867.21 ms per token,     1.15 tokens per second)
# llama_print_timings:       total time =   32120.37 ms /    44 tokens
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =    6702.78 ms
# llama_print_timings:      sample time =      14.91 ms /    16 runs   (    0.93 ms per token,  1073.18 tokens per second)
# llama_print_timings: prompt eval time =    6742.05 ms /    14 tokens (  481.58 ms per token,     2.08 tokens per second)
# llama_print_timings:        eval time =   12781.39 ms /    15 runs   (  852.09 ms per token,     1.17 tokens per second)
# llama_print_timings:       total time =   19554.72 ms /    29 tokens
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =    6702.78 ms
# llama_print_timings:      sample time =      20.37 ms /    22 runs   (    0.93 ms per token,  1080.28 tokens per second)
# llama_print_timings: prompt eval time =    6920.34 ms /    11 tokens (  629.12 ms per token,     1.59 tokens per second)
# llama_print_timings:        eval time =   17473.52 ms /    21 runs   (  832.07 ms per token,     1.20 tokens per second)
# llama_print_timings:       total time =   24436.26 ms /    32 tokens
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =    6702.78 ms
# llama_print_timings:      sample time =      17.91 ms /    19 runs   (    0.94 ms per token,  1060.62 tokens per second)
# llama_print_timings: prompt eval time =    6434.10 ms /    10 tokens (  643.41 ms per token,     1.55 tokens per second)
# llama_print_timings:        eval time =   15067.31 ms /    18 runs   (  837.07 ms per token,     1.19 tokens per second)
# llama_print_timings:       total time =   21538.30 ms /    28 tokens
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =    6702.78 ms
# llama_print_timings:      sample time =      24.61 ms /    25 runs   (    0.98 ms per token,  1015.81 tokens per second)
# llama_print_timings: prompt eval time =    7193.49 ms /    15 tokens (  479.57 ms per token,     2.09 tokens per second)
# llama_print_timings:        eval time =   20791.26 ms /    24 runs   (  866.30 ms per token,     1.15 tokens per second)
# llama_print_timings:       total time =   28037.19 ms /    39 tokens
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =    6702.78 ms
# llama_print_timings:      sample time =      29.35 ms /    29 runs   (    1.01 ms per token,   988.01 tokens per second)
# llama_print_timings: prompt eval time =    9156.26 ms /    16 tokens (  572.27 ms per token,     1.75 tokens per second)
# llama_print_timings:        eval time =   24775.27 ms /    29 runs   (  854.32 ms per token,     1.17 tokens per second)
# llama_print_timings:       total time =   33991.86 ms /    45 tokens
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =    6702.78 ms
# llama_print_timings:      sample time =      28.62 ms /    28 runs   (    1.02 ms per token,   978.27 tokens per second)
# llama_print_timings: prompt eval time =   16346.19 ms /    30 tokens (  544.87 ms per token,     1.84 tokens per second)
# llama_print_timings:        eval time =   23144.67 ms /    27 runs   (  857.21 ms per token,     1.17 tokens per second)
# llama_print_timings:       total time =   39550.69 ms /    57 tokens
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =    6702.78 ms
# llama_print_timings:      sample time =      29.16 ms /    30 runs   (    0.97 ms per token,  1028.67 tokens per second)
# llama_print_timings: prompt eval time =   16378.50 ms /    30 tokens (  545.95 ms per token,     1.83 tokens per second)
# llama_print_timings:        eval time =   24926.09 ms /    29 runs   (  859.52 ms per token,     1.16 tokens per second)
# llama_print_timings:       total time =   41368.43 ms /    59 tokens
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =    6702.78 ms
# llama_print_timings:      sample time =      23.29 ms /    24 runs   (    0.97 ms per token,  1030.71 tokens per second)
# llama_print_timings: prompt eval time =    6334.24 ms /    13 tokens (  487.25 ms per token,     2.05 tokens per second)
# llama_print_timings:        eval time =   19956.69 ms /    23 runs   (  867.68 ms per token,     1.15 tokens per second)
# llama_print_timings:       total time =   26340.32 ms /    36 tokens
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =    6702.78 ms
# llama_print_timings:      sample time =      34.47 ms /    35 runs   (    0.98 ms per token,  1015.29 tokens per second)
# llama_print_timings: prompt eval time =    5810.60 ms /    12 tokens (  484.22 ms per token,     2.07 tokens per second)
# llama_print_timings:        eval time =   29036.67 ms /    34 runs   (  854.02 ms per token,     1.17 tokens per second)
# llama_print_timings:       total time =   34918.21 ms /    46 tokens
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =    6702.78 ms
# llama_print_timings:      sample time =      49.21 ms /    44 runs   (    1.12 ms per token,   894.07 tokens per second)
# llama_print_timings: prompt eval time =   17561.77 ms /    19 tokens (  924.30 ms per token,     1.08 tokens per second)
# llama_print_timings:        eval time =   38477.47 ms /    43 runs   (  894.82 ms per token,     1.12 tokens per second)
# llama_print_timings:       total time =   56137.95 ms /    62 tokens
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =    6702.78 ms
# llama_print_timings:      sample time =      30.21 ms /    29 runs   (    1.04 ms per token,   959.85 tokens per second)
# llama_print_timings: prompt eval time =    9743.95 ms /    18 tokens (  541.33 ms per token,     1.85 tokens per second)
# llama_print_timings:        eval time =   23716.20 ms /    28 runs   (  847.01 ms per token,     1.18 tokens per second)
# llama_print_timings:       total time =   33522.08 ms /    46 tokens
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =    6702.78 ms
# llama_print_timings:      sample time =      66.82 ms /    60 runs   (    1.11 ms per token,   897.91 tokens per second)
# llama_print_timings: prompt eval time =   10776.85 ms /    19 tokens (  567.20 ms per token,     1.76 tokens per second)
# llama_print_timings:        eval time =   66733.14 ms /    59 runs   ( 1131.07 ms per token,     0.88 tokens per second)
# llama_print_timings:       total time =   77656.39 ms /    78 tokens
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =    6702.78 ms
# llama_print_timings:      sample time =      47.95 ms /    47 runs   (    1.02 ms per token,   980.29 tokens per second)
# llama_print_timings: prompt eval time =    9083.91 ms /    16 tokens (  567.74 ms per token,     1.76 tokens per second)
# llama_print_timings:        eval time =   40750.14 ms /    47 runs   (  867.02 ms per token,     1.15 tokens per second)
# llama_print_timings:       total time =   49932.55 ms /    63 tokens
# time taken to execute 20 SQL queries on cpu: 645.0212495769997

# %%
import pandas as pd
ground_truth = [
    "SELECT * FROM Employees WHERE EmployeeID < 10;",
    "SELECT FirstName, Salary FROM Employees WHERE Department = 'IT';",
    "SELECT Department, COUNT(*) AS NumEmployees FROM Employees GROUP BY Department;",
    "SELECT * FROM Employees WHERE Salary > 70000;",
    "SELECT * FROM Employees ORDER BY LastName DESC;",
    "SELECT AVG(Salary) AS AvgSalary FROM Employees;",
    "SELECT * FROM EmployeeDetails WHERE BirthDate > '1982-01-01'",
    "SELECT * FROM Employees WHERE FirstName LIKE 'J%';",
    "SELECT * FROM Employees ORDER BY Department, Position;",
    "SELECT * FROM Employees WHERE Department IS NULL;",
    "SELECT E.*, ED.BirthDate, ED.Address, ED.City, ED.State, ED.ZipCode, ED.Phone FROM Employees E JOIN EmployeeDetails ED ON E.EmployeeID = ED.EmployeeID;",
    "SELECT Department, COUNT(*) AS NumEmployees, AVG(Salary) AS AvgSalary FROM Employees GROUP BY Department;",
    "SELECT ed.City, COUNT(ed.EmployeeID) AS EmployeeCount, GROUP_CONCAT(e.FirstName, ' ', e.LastName) AS EmployeeNames FROM EmployeeDetails ed JOIN Employees e ON ed.EmployeeID = e.EmployeeID GROUP BY ed.City HAVING COUNT(ed.EmployeeID) > 1 ORDER BY EmployeeCount DESC;",
    "SELECT * FROM Employees WHERE Salary BETWEEN 60000 AND 80000 ORDER BY Salary;",
    "SELECT * FROM Employees ORDER BY Salary DESC LIMIT 3;",
    "SELECT Department, AVG(Salary) AS AvgSalary FROM Employees GROUP BY Department ORDER BY AvgSalary DESC LIMIT 1;",
    "SELECT E.* FROM Employees E JOIN (SELECT Department, AVG(Salary) AS AvgSalary FROM Employees GROUP BY Department) AS AvgSalaries ON E.Department = AvgSalaries.Department WHERE E.Salary > AvgSalaries.AvgSalary;",
    "SELECT ED.City, COUNT(*) AS NumEmployees, AVG(E.Salary) AS AvgSalary FROM Employees E JOIN EmployeeDetails ED ON E.EmployeeID = ED.EmployeeID GROUP BY ED.City;",
    "SELECT e.FirstName, e.LastName, ed.BirthDate, TIMESTAMPDIFF(YEAR, ed.BirthDate, CURDATE()) AS Age, CASE WHEN ed.BirthDate = (SELECT MIN(BirthDate) FROM EmployeeDetails) THEN 'Oldest' WHEN ed.BirthDate = (SELECT MAX(BirthDate) FROM EmployeeDetails) THEN 'Youngest' END AS AgeCategory FROM EmployeeDetails ed JOIN Employees e ON ed.EmployeeID = e.EmployeeID WHERE ed.BirthDate = (SELECT MIN(BirthDate) FROM EmployeeDetails) OR ed.BirthDate = (SELECT MAX(BirthDate) FROM EmployeeDetails);",
    "SELECT E1.EmployeeID, E1.FirstName, E1.LastName FROM Employees E1 JOIN Employees E2 ON E1.LastName = E2.LastName AND E1.EmployeeID != E2.EmployeeID;"
]

# Create a DataFrame
df = pd.DataFrame({
    'Question': sql_questions,
    'Ground Truth Query':ground_truth ,
    'Granite Response (LLM)': model_response ,
    'Query Level':['simple','simple','simple','simple','simple','simple','simple','simple','simple','simple','medium','medium','medium','medium','medium','complex','complex','complex','complex','complex'],
    'Match':['correct','correct' ,'correct','correct','correct','correct' ,'correct','correct','correct','correct','correct','correct','wrong','correct','wrong','correct','correct','wrong','wrong','correct']
})
# Out:
# Exception ignored in: <function Llama.__del__ at 0x7994afd0ac20>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/llama_cpp/llama.py", line 1972, in __del__
#     self.close()
#   File "/usr/local/lib/python3.10/dist-packages/llama_cpp/llama.py", line 1969, in close
#     self._stack.close()
# AttributeError: 'Llama' object has no attribute '_stack'

# %%
df
# Out:
#                                              Question  \
# 0   Retrieve all columns for employees with an Emp...
# 1   Retrieve the first name and salary of employee...
# 2   Count the number of employees in each department.
# 3   Retrieve employees whose salary is greater tha...
# 4   Retrieve employees sorted by last name in desc...
# 5          Calculate the average salary of employees.
# 6   Retrieve employees birth after January 1st, 1982.
# 7   Retrieve employees with the first name startin...
# 8   Retrieve employees sorted by department and po...
# 9     Retrieve employees with no assigned department.
# 10  Retrieve employees along with their detailed i...
# 11  Calculate the total number of employees and av...
# 12  Retrieve the employee details who live in citi...
# 13  Retrieve employees with salaries between $60,0...
# 14         Retrieve the top 3 highest paid employees.
# 15  Retrieve the department with the highest avera...
# 16  Retrieve employees who are earning more than t...
# 17  Retrieve the total number of employees in each...
# 18  Retrieve the youngest and oldest employees' de...
# 19  Retrieve employees who have the same last name...
#
#                                    Ground Truth Query  \
# 0      SELECT * FROM Employees WHERE EmployeeID < 10;
# 1   SELECT FirstName, Salary FROM Employees WHERE ...
# 2   SELECT Department, COUNT(*) AS NumEmployees FR...
# 3       SELECT * FROM Employees WHERE Salary > 70000;
# 4     SELECT * FROM Employees ORDER BY LastName DESC;
# 5     SELECT AVG(Salary) AS AvgSalary FROM Employees;
# 6   SELECT * FROM EmployeeDetails WHERE BirthDate ...
# 7   SELECT * FROM Employees WHERE FirstName LIKE '...
# 8   SELECT * FROM Employees ORDER BY Department, P...
# 9   SELECT * FROM Employees WHERE Department IS NULL;
# 10  SELECT E.*, ED.BirthDate, ED.Address, ED.City,...
# 11  SELECT Department, COUNT(*) AS NumEmployees, A...
# 12  SELECT ed.City, COUNT(ed.EmployeeID) AS Employ...
# 13  SELECT * FROM Employees WHERE Salary BETWEEN 6...
# 14  SELECT * FROM Employees ORDER BY Salary DESC L...
# 15  SELECT Department, AVG(Salary) AS AvgSalary FR...
# 16  SELECT E.* FROM Employees E JOIN (SELECT Depar...
# 17  SELECT ED.City, COUNT(*) AS NumEmployees, AVG(...
# 18  SELECT e.FirstName, e.LastName, ed.BirthDate, ...
# 19  SELECT E1.EmployeeID, E1.FirstName, E1.LastNam...
#
#                                Granite Response (LLM) Query Level    Match
# 0   SELECT * FROM Employees WHERE EmployeeID < 10;...      simple  correct
# 1   SELECT FirstName, Salary FROM Employees WHERE ...      simple  correct
# 2   SELECT COUNT(*) AS NumberOfEmployees, Departme...      simple  correct
# 3   SELECT * FROM Employees WHERE Salary > 70000;\...      simple  correct
# 4   SELECT * FROM Employees ORDER BY LastName DESC...      simple  correct
# 5   SELECT AVG(Salary) AS AverageSalary FROM Emplo...      simple  correct
# 6   SELECT * FROM EmployeeDetails WHERE BirthDate ...      simple  correct
# 7   SELECT * FROM Employees WHERE FirstName LIKE '...      simple  correct
# 8   SELECT FirstName, LastName, Department, Positi...      simple  correct
# 9   SELECT FirstName, LastName, Email FROM Employe...      simple  correct
# 10  SELECT * FROM Employees\nJOIN EmployeeDetails ...      medium  correct
# 11  SELECT COUNT(*) AS TotalEmployees, Department,...      medium  correct
# 12  SELECT City, COUNT(*) AS EmployeeCount\nFROM E...      medium    wrong
# 13  SELECT * FROM Employees WHERE Salary BETWEEN 6...      medium  correct
# 14  SELECT TOP 3 FirstName, LastName, Salary FROM ...      medium    wrong
# 15  SELECT Department, AVG(Salary) AS AvgSalary\nF...     complex  correct
# 16  SELECT FirstName, LastName, Salary \nFROM Empl...     complex  correct
# 17  SELECT City, COUNT(*) AS TotalEmployees, AVG(S...     complex    wrong
# 18  SELECT FirstName, LastName, Age\nFROM (\n    S...     complex    wrong
# 19  SELECT FirstName, LastName, Email \nFROM Emplo...     complex  correct

# %% [markdown]
# **Time took to execute 20 queries on cpu = 645 seconds which is appro. 11 minutes**
